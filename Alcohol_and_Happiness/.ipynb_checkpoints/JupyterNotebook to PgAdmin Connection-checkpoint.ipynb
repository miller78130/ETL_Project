# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#Store-all-CSV-into-DataFrames

# %%
WH_csv = "Resources/world-happiness-report-2021.csv"
wh_df = pd.read_csv(WH_csv)
wh_df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
HP_csv = "Resources/HappinessAlcoholConsumption.csv"
HP_df = pd.read_csv(HP_csv)
HP_df
# Out:
#          Country                           Region Hemisphere  HappinessScore  \
# 0        Denmark                   Western Europe      north           7.526
# 1    Switzerland                   Western Europe      north           7.509
# 2        Iceland                   Western Europe      north           7.501
# 3         Norway                   Western Europe      north           7.498
# 4        Finland                   Western Europe      north           7.413
# ..           ...                              ...        ...             ...
# 117     Tanzania               Sub-Saharan Africa      south           3.666
# 118      Liberia               Sub-Saharan Africa      north           3.622
# 119        Benin               Sub-Saharan Africa      north           3.484
# 120         Togo               Sub-Saharan Africa      north           3.303
# 121        Syria  Middle East and Northern Africa      north           3.069
#
# ...

# %%
LE_csv = "Resources/LifeExpectancy1.csv"
LE_df = pd.read_csv(LE_csv)
LE_df
# Out:
#       CountryName                           IndicatorName  Year 2019
# 0           Aruba  Life expectancy at birth, male (years)     73.768
# 1     Afghanistan  Life expectancy at birth, male (years)     63.382
# 2          Angola  Life expectancy at birth, male (years)     58.416
# 3         Albania  Life expectancy at birth, male (years)     77.002
# 4         Andorra  Life expectancy at birth, male (years)     66.783
# ..            ...                                     ...        ...
# 259        Kosovo  Life expectancy at birth, male (years)     70.300
# 260   Yemen, Rep.  Life expectancy at birth, male (years)     64.443
# 261  South Africa  Life expectancy at birth, male (years)     60.726
# 262        Zambia  Life expectancy at birth, male (years)     60.848
# 263      Zimbabwe  Life expectancy at birth, male (years)     59.798
#
# [264 rows x 3 columns]

# %%
#Created-a-team-password-in-pgAdmin-to-expire-Thurs-June-17,-2021

# %%
rds_connection_string = "ProjectETL:tempPW@localhost:5432/ETL"
engine = create_engine(f'postgresql://{rds_connection_string}', pool_size=10, max_overflow=20)

# %%
engine.table_names()
# Out:
# ['happinessalcoholconsumption', 'worldhappinessreport2021', 'lifeexpectancy']

# %%
#Reading-all-3-tables-from-SQL-to-pandas

# %%
pd.read_sql_query('select * from HappinessAlcoholConsumption', con=engine).head()
# Out:
#        country          region hemisphere  happinessscore    hdi  \
# 0      Denmark  Western Europe      north           7.526  928.0
# 1  Switzerland  Western Europe      north           7.509  943.0
# 2      Iceland  Western Europe      north           7.501  933.0
# 3       Norway  Western Europe      north           7.498  951.0
# 4      Finland  Western Europe      north           7.413  918.0
#
#    gdp_percapita  beer_percapita  spirit_percapita  wine_percapita
# 0         53.579           224.0              81.0           278.0
# 1         79.866           185.0             100.0           280.0
# 2         60.530           233.0              61.0            78.0
# 3         70.890           169.0              71.0           129.0
# 4         43.433           263.0             133.0            97.0

# %%
pd.read_sql_query('select * from lifeexpectancy', con=engine).head()
# Out:
#    countryname                           indicatorname  year_2019
# 0        Aruba  Life expectancy at birth, male (years)     73.768
# 1  Afghanistan  Life expectancy at birth, male (years)     63.382
# 2       Angola  Life expectancy at birth, male (years)     58.416
# 3      Albania  Life expectancy at birth, male (years)     77.002
# 4      Andorra  Life expectancy at birth, male (years)     66.783

# %%
pd.read_sql_query('select * from worldhappinessreport2021', con=engine).head()
# Out:
#   country_name reginal_indicator  ladder_score  \
# 0      Finland    Western Europe         7.842
# 1      Denmark    Western Europe         7.620
# 2  Switzerland    Western Europe         7.571
# 3      Iceland    Western Europe         7.554
# 4  Netherlands    Western Europe         7.464
#
#    standard_error_of_ladder_score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    logged_gdp_per_capita  social_support  healthy_life_expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
#Join-3-tables-to-1-csv,-without-selecting-every-single-column

# %%
HP_LE_WH_csv = "Resources/Joins HP_LE_WH.csv"
Joins_df = pd.read_csv(HP_LE_WH_csv)
Joins_df
# Out:
#      countryname  happinessscore  healthy_life_expectancy  year_2019  \
# 0        Denmark           7.526                   72.700     79.300
# 1    Switzerland           7.509                   74.400     81.900
# 2        Iceland           7.501                   73.000     81.000
# 3         Norway           7.498                   73.300     81.200
# 4        Finland           7.413                   72.000     79.200
# ..           ...             ...                      ...        ...
# 117     Tanzania           3.666                   57.999     63.643
# 118      Liberia           3.622                   56.498     62.715
# 119        Benin           3.484                   54.713     60.201
# 120         Togo           3.303                   54.914     60.152
# 121          NaN           3.069                      NaN        NaN
#
#      social_support  generosity  beer_percapita  spirit_percapita  \
# 0             0.954       0.030             224                81
# ...

# %%
#Clean-DataFrame

# %%
Joins_NewCut_df = Joins_df[['countryname', 'happinessscore', 'healthy_life_expectancy']].copy()
Joins_NewCut_df.head(10)
# Out:
#    countryname  happinessscore  healthy_life_expectancy
# 0      Denmark           7.526                     72.7
# 1  Switzerland           7.509                     74.4
# 2      Iceland           7.501                     73.0
# 3       Norway           7.498                     73.3
# 4      Finland           7.413                     72.0
# 5       Canada           7.404                     73.8
# 6  Netherlands           7.339                     72.4
# 7  New Zealand           7.334                     73.4
# 8    Australia           7.313                     73.9
# 9       Sweden           7.291                     72.7

# %%
# Add-Clean-DataFrame-to-SQL

# %%
Joins_NewCut_df.to_sql(name='Joins_NewCut', con=engine, if_exists='append', index=False)

# %%
#Check-for-tables

# %%
engine.table_names()
# Out:
# ['happinessalcoholconsumption',
#  'worldhappinessreport2021',
#  'lifeexpectancy',
#  'Joins_NewCut']

# %%
Joins_csv = "Resources/Joins.csv"
Joins_NewCut_df = pd.read_csv(Joins_csv)
Joins_NewCut_df
# Out:
#      countryname  happinessscore  healthy_life_expectancy
# 0        Denmark           7.526                   72.700
# 1    Switzerland           7.509                   74.400
# 2        Iceland           7.501                   73.000
# 3         Norway           7.498                   73.300
# 4        Finland           7.413                   72.000
# ..           ...             ...                      ...
# 117     Tanzania           3.666                   57.999
# 118      Liberia           3.622                   56.498
# 119        Benin           3.484                   54.713
# 120         Togo           3.303                   54.914
# 121          NaN           3.069                      NaN
#
# [122 rows x 3 columns]

# %%
engine.table_names()
# Out:
# ['happinessalcoholconsumption',
#  'worldhappinessreport2021',
#  'lifeexpectancy',
#  'Joins_NewCut']

# %%
#Load-DataFrames-into-database

# %%
pd.read_sql_query('select * from public."Joins_NewCut"', con=engine).head()
# Out:
#    countryname  happinessscore  healthy_life_expectancy
# 0      Denmark           7.526                     72.7
# 1  Switzerland           7.509                     74.4
# 2      Iceland           7.501                     73.0
# 3       Norway           7.498                     73.3
# 4      Finland           7.413                     72.0
